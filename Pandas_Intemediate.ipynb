# %% [markdown]
# #Pandas

# %%
import pandas as pd

# %% [markdown]
# ##Get Data

# %%
url = 'https://raw.githubusercontent.com/norochalise/pandas-tutorial-article-2022/main/dataset/online_store_customer_data.csv'

# %%
data = pd.read_csv(url,on_bad_lines='skip')

# %% [markdown]
# ##Basics

# %%
data.head(5)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
data.tail(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15

# %%
data.sample(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 1097       12/27/2019          152285  Female  59.0        Married
# 945         11/6/2019          152133    Male  19.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 1725         8/8/2020          152913    Male  34.0         Single
# 2362        3/14/2021          153550  Female  50.0        Married
#
#        State_names   Segment Employees_status Payment_method  Referal  \
# 1097       Alabama  Platinum          workers           Card      1.0
# 945   Rhode Island     Basic     Unemployment          Other      1.0
# 3         Virginia  Platinum          workers           Card      1.0
# 1725      Delaware     Basic        Employees          Other      0.0
# 2362        Nevada     Basic    self-employed         PayPal      1.0
#
#       Amount_spent
# 1097       2747.99
# 945         536.85
# 3          1199.79
# 1725       1086.39
# 2362       1837.98

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.drop_duplicates(keep = 'first', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2500 non-null   object
#  1   Transaction_ID    2500 non-null   int64
#  2   Gender            2472 non-null   object
#  3   Age               2458 non-null   float64
#  4   Marital_status    2500 non-null   object
#  5   State             2500 non-null   object
#  6   Segment           2500 non-null   object
#  7   Employees_status  2474 non-null   object
#  8   Payment_method    2500 non-null   object
#  9   Referal           2346 non-null   float64
#  10  Amount_spent      2259 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 234.4+ KB

# %%
data.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2470.000000  2357.000000   2270.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.186277     0.476405    878.507451
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    678.192500
# 50%     152443.500000    47.000000     1.000000   1341.435000
# 75%     153071.250000    62.000000     1.000000   2038.102500
# max     153699.000000    78.000000     1.000000   2999.980000

# %% [markdown]
# ##Slicing

# %%
data.iloc[0:10,2:5]
# Out:
#    Gender   Age Marital_status
# 0  Female  19.0         Single
# 1    Male  49.0         Single
# 2    Male  63.0        Married
# 3     NaN  18.0         Single
# 4    Male  27.0         Single
# 5    Male  71.0         Single
# 6  Female  34.0        Married
# 7    Male  37.0        Married
# 8    Male  75.0        Married
# 9  Female  41.0        Married

# %%
data.rename(columns={'Transaction_date': 'Date', 'State_names': 'State'},inplace=True)
data.head(5)
# Out:
#        Date  Transaction_ID  Gender   Age Marital_status        State  \
# 0  1/1/2019          151200  Female  19.0         Single       Kansas
# 1  1/1/2019          151201    Male  49.0         Single     Illinois
# 2  1/1/2019          151202    Male  63.0        Married   New Mexico
# 3  1/1/2019          151203     NaN  18.0         Single     Virginia
# 4  1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
data[(data['Age'] >= 45) & (data['Age'] < 60)]
# Out:
#            Date  Transaction_ID  Gender   Age Marital_status           State  \
# 1      1/1/2019          151201    Male  49.0         Single        Illinois
# 10     1/4/2019          151210  Female  56.0        Married      California
# 13     1/5/2019          151213    Male  47.0         Single  South Carolina
# 19     1/8/2019          151219  Female  46.0        Married        Missouri
# 22     1/8/2019          151222  Female  50.0        Married            Ohio
# ...         ...             ...     ...   ...            ...             ...
# 2494  4/27/2021          153682    Male  56.0        Married       Wisconsin
# 2498  4/28/2021          153686  Female  55.0         Single            Ohio
# 2505  4/30/2021          153693    Male  54.0        Married         Alabama
# 2507   5/1/2021          153695  Female  57.0         Single  South Carolina
# 2511   5/1/2021          153699    Male  48.0         Single      California
#
# ...

# %% [markdown]
# ##Data

# %%
data
